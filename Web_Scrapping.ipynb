# %% [markdown]
# <a href="https://colab.research.google.com/github/Chirag314/Webscrapping/blob/main/Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Reference
# [Datacamp](https://www.datacamp.com/tutorial/web-scraping-using-python)

# %%
# Web Scrapping with Python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Import libraries for url manipulation
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url="https://www.nurseryrhymes.org/nursery-rhymes.html"
html=urlopen(url)

# %%
soup=BeautifulSoup(html,'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Get the title
title=soup.title
print(title)
# Out:
# <title>List of Nursery Rhymes, Alphabetically</title>

# %%
# Check the text on webpages
text=soup.get_text()
print(soup.text)
# Out:
# List of Nursery Rhymes, Alphabetically
#
#
#
#
# var __adobewebfontsappname__="dreamweaver"
#
#
# a:link {
# 	text-decoration: none;
# }
# a:visited {
# 	text-decoration: none;
# }
# a:hover {
# 	text-decoration: none;
# }
# a:active {
# 	text-decoration: none;
# }
#
#
#
#
#   (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-1018552407673214",
#     enable_page_level_ads: true
#   });
#
# (function(){/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# ...

# %%
all_links=soup.find_all('a')
for link in all_links:
  print(link.get("href"))
# Out:
# https://www.nurseryrhymes.org
# nursery-rhymes.html
# #
# animals.html
# body.html
# flowers.html
# food.html
# transport.html
# weather.html
# rain.html
# summer.html
# winter-snow.html
# #
# christmas-songs.html
# easter.html
# thanksgiving.html
# learning.html
# alphabet.html
# numbers.html
# lullaby.html
# nursery-rhymes-for-babies.html
# clapping-games.html
# fingerplay.html
# tongue-twisters.html
# a-sailor-went-to-sea.html
# a-tisket-a-tasket.html
# a-wise-old-owl.html
# a-you-re-adorable.html
# abc-song.html
# aiken-drum.html
# alice-the-camel.html
# all-the-pretty-little-horses.html
# alphabet-song.html
# animal-alphabet-song.html
# the-animal-fair.html
# apple-on-a-stick.html
# apple-pie-abc.html
# apple-pie-abc-short.html
# baa-baa-black-sheep.html
# baby-bumble-bee.html
# betty-botter.html
# billy-boy.html
# bingo.html
# blow-wind-blow.html
# bobby-shaftoes-gone-to-the-sea.html
# brahms-lullaby.html
# brother-john.html
# brush-brush-brush-your-teeth.html
# ...

# %%
# Check one song
url="https://www.nurseryrhymes.org/a-sailor-went-to-sea.html"
html=urlopen(url)
soup=BeautifulSoup(html,'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
all_links=soup.find_all('em')
#for link in all_links:
#print(link.get("href"))

# %%
all_links
# Out:
# [<em>A sailor went to sea, sea, sea <br/>
#          To see what he could see, see, see <br/>
#          But all that he could see, see, see <br/>
#          Was the bottom of the deep blue sea, sea, sea!<br/>
#  <br/>
#          A sailor went to knee, knee, knee <br/>
#          To see what he could knee, knee, knee <br/>
#          But all that he could knee, knee, knee <br/>
#          Was the bottom of the deep blue knee, knee, knee! <br/>
#          (Sea, sea, sea)<br/>
#  <br/>
#          A sailor went to chop, chop, chop<br/>
#          To see what he could chop, chop, chop<br/>
#          But all that he could chop, chop, chop <br/>
#          Was the bottom of the deep blue chop, chop, chop! <br/>
#          (Sea, sea, sea)<br/>
#          (Knee, knee, knee) </em>]
